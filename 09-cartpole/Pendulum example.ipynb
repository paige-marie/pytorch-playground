# %% [markdown]
# The state is represented by 4 numbers:
#
# The cart position x from -2.4 to 2.4.
#
# The cart velocity v
#
# The pole angle θ with respect to the vertical from -12 to 12 degrees (from -0.21 to 0.21 in radians)
#
# The pole angular velocity ω. This is the rate of change of θ.

# %%
import argparse
import gymnasium as gym
import numpy as np
from itertools import count
from random import random

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.distributions import Categorical

from pendulum import PendulumEnv

# %%
#env = gym.make('CartPole-v1', render_mode="human")
env = PendulumEnv(render_mode='human')
#print(env._max_episode_steps)

# %%
#floats between -2.0 and 2.0
import random
def select_action_random(state):
    rand = random.uniform(-2.0, 2.0)
    return [rand]
    

def goodness_score(select_action, num_episodes=100):
    num_steps = 500
    ts = []
    #for episode in range(1):
    for episode in range(num_episodes):
#         state = env.reset(options={"x_init":np.pi, "y_init":1.0})[0]
        state = env.reset()[0]
        print("observation state is ", state)
        for t in range(1, num_steps+1):
            #print(state)
            action = select_action(state)
            print("action is ", action)
            state, reward, done, truncated, info = env.step(action)
            if done:
                break
        ts.append(t)
    score = sum(ts) / (len(ts)*num_steps)
    return score

print(goodness_score(select_action_random))
# Out:
# high is  [0. 2.]
# observation state is  [1.       0.       1.522057]
# action is  [0.967244835836444]
# state is :  [0.         1.52205703]
# action is  [-0.6559884580195035]
# state is :  [0.08335719 1.66714376]
# action is  [0.1203024188609394]
# state is :  [0.16491674 1.63119101]
# action is  [-0.019422479172332086]
# state is :  [0.25353494 1.77236402]
# action is  [1.2367280532600242]
# state is :  [0.3514135  1.95757124]
# action is  [1.0670037494586877]
# state is :  [0.47147597 2.4012494 ]
# action is  [-0.3810783142118095]
# state is :  [0.61657353 2.90195125]
# action is  [1.0247840834852755]
# state is :  [0.78049712 3.27847177]
# action is  [-1.918223519747344]
# state is :  [0.97849282 3.95991394]
# high is  [0. 2.]
# observation state is  [1.        0.        1.4215187]
# action is  [1.1076126977811778]
# state is :  [0.         1.42151867]
# action is  [-1.6156365032732314]
# state is :  [0.07938303 1.58766058]
# action is  [-0.7874652234643529]
# state is :  [0.14962252 1.40478986]
# action is  [-0.7573603372892319]
# state is :  [0.21954596 1.39846874]
# action is  [0.5279618491009788]
# state is :  [0.29195619 1.44820456]
# action is  [-1.534182487786289]
# state is :  [0.37911961 1.74326848]
# action is  [-0.8900788290171011]
# state is :  [0.46865552 1.79071816]
# action is  [1.3267540903777526]
# state is :  [0.5684541  1.99597172]
# action is  [-0.4504829332532587]
# state is :  [0.69839072 2.59873227]
# action is  [1.5735549691731792]
# state is :  [0.84906068 3.01339933]
# action is  [0.7825312654401126]
# state is :  [1.03968207 3.81242769]
# high is  [0. 2.]
# observation state is  [ 1.          0.         -0.51705825]
# action is  [1.2638773851702463]
# state is :  [ 0.         -0.51705823]
# high is  [0. 2.]
# observation state is  [1.        0.        1.0174115]
# action is  [-0.8010815737482737]
# state is :  [0.         1.01741144]
# action is  [-1.6887638304103727]
# state is :  [0.04486246 0.8972492 ]
# action is  [-1.1767680689624607]
# state is :  [0.07874097 0.67757019]
# action is  [-0.8950198724652982]
# state is :  [0.10674345 0.5600497 ]
# action is  [-0.960467142497134]
# state is :  [0.13202857 0.50570237]
# action is  [-0.4777252642730794]
# state is :  [0.15504689 0.46036629]
# action is  [0.19533867956488038]
# state is :  [0.18027325 0.50452732]
# action is  [-1.1131626304104256]
# state is :  [0.21368835 0.66830193]
# action is  [-0.9735972528768237]
# state is :  [0.24670719 0.66037688]
# action is  [0.46772453715703577]
# state is :  [0.28158202 0.69749643]
# action is  [-0.8118159710156791]
# state is :  [0.33038511 0.97606189]
# action is  [0.4836539306812164]
# state is :  [0.38526486 1.09759499]
# action is  [-1.597942292905672]
# state is :  [0.45786469 1.45199653]
# action is  [1.2542794516725873]
# state is :  [0.53505621 1.54383049]
# action is  [-0.05534022327644017]
# state is :  [0.64077568 2.11438945]
# action is  [-0.24205716191262505]
# state is :  [0.76849826 2.55445149]
# action is  [-1.9695216767567905]
# state is :  [0.92047002 3.03943517]
# high is  [0. 2.]
# observation state is  [ 1.         0.        -0.8826643]
# action is  [1.6089114489834664]
# state is :  [ 0.        -0.8826643]
# high is  [0. 2.]
# observation state is  [1.         0.         0.75417155]
# action is  [0.27358145188676986]
# state is :  [0.         0.75417156]
# action is  [0.8271739435976397]
# state is :  [0.03976044 0.79520878]
# action is  [0.52898232522405]
# state is :  [0.08721531 0.94909735]
# action is  [0.49614503566002366]
# state is :  [0.14190397 1.09377328]
# action is  [-0.10377325168273765]
# state is :  [0.20561728 1.27426619]
# action is  [-0.0921550309364001]
# state is :  [0.27620872 1.41182881]
# action is  [1.3117790684453126]
# state is :  [0.35633562 1.60253808]
# action is  [-0.2338890341167028]
# state is :  [0.45938246 2.06093674]
# action is  [1.7921971281723121]
# state is :  [0.57730243 2.35839939]
# action is  [0.021836183208404414]
# state is :  [0.72913009 3.03655311]
# action is  [0.09661780582839485]
# state is :  [0.90610481 3.5394944 ]
# high is  [0. 2.]
# observation state is  [ 1.          0.         -0.62065357]
# action is  [-1.2121827647132672]
# state is :  [ 0.         -0.62065356]
# high is  [0. 2.]
# observation state is  [1.        0.        1.2313533]
# action is  [1.315220539967045]
# state is :  [0.         1.23135334]
# action is  [-1.132946817331527]
# state is :  [0.07143182 1.42863642]
# action is  [-0.3952232272672296]
# state is :  [0.13704296 1.31222271]
# action is  [0.39610051666519164]
# state is :  [0.20481296 1.35540003]
# action is  [1.5393332714948809]
# state is :  [0.28318061 1.56735313]
# action is  [-0.8971191959794598]
# state is :  [0.38357118 2.00781136]
# action is  [1.7389263865757054]
# state is :  [0.49126715 2.15391938]
# action is  [0.6812746488323795]
# state is :  [0.62969545 2.76856601]
# action is  [0.17283103946483847]
# state is :  [0.79531701 3.31243119]
# action is  [1.2902503061584336]
# state is :  [0.98901301 3.87392002]
# high is  [0. 2.]
# observation state is  [1.         0.         0.05449689]
# action is  [1.580694653810161]
# state is :  [0.         0.05449689]
# action is  [-1.6895628064596115]
# state is :  [0.01458005 0.29160109]
# action is  [1.0042590359006507]
# state is :  [0.01703512 0.04910132]
# action is  [1.4753184474176737]
# state is :  [0.02766092 0.2125159 ]
# action is  [-0.14512513010859296]
# state is :  [0.05038875 0.45455671]
# action is  [-0.5730006790975128]
# state is :  [0.07391693 0.47056351]
# action is  [1.9811855465267176]
# state is :  [0.09591696 0.44000063]
# action is  [-1.6979415941218532]
# state is :  [0.13636725 0.80900593]
# action is  [0.8566571851846563]
# state is :  [0.16918093 0.65627344]
# action is  [-1.0027841603914363]
# state is :  [0.21473359 0.91105329]
# action is  [1.049148483373831]
# state is :  [0.26075614 0.92045102]
# action is  [1.0755693711426786]
# state is :  [0.32431523 1.2711817 ]
# action is  [-1.0884402924133925]
# state is :  [0.40789082 1.67151194]
# action is  [-0.5110681059502369]
# state is :  [0.4981784  1.80575145]
# action is  [1.5151633801279907]
# state is :  [0.60255144 2.08746084]
# action is  [-0.2792309880666983]
# state is :  [0.7395412  2.73979517]
# action is  [-0.9023532555610658]
# state is :  [0.89970981 3.20337229]
# high is  [0. 2.]
# observation state is  [1.        0.        1.8294423]
# action is  [1.0629375713142104]
# state is :  [0.         1.82944228]
# action is  [-1.1802822389102614]
# state is :  [0.09944415 1.98888292]
# action is  [0.6427780652424562]
# state is :  [0.19375919 1.88630083]
# action is  [-0.5037574748213718]
# state is :  [0.30011565 2.12712935]
# action is  [-1.062340697097809]
# state is :  [0.41378009 2.27328875]
# action is  [-0.6315826898866885]
# state is :  [0.53455472 2.4154926 ]
# action is  [0.9852918395576551]
# state is :  [0.66969716 2.70284865]
# action is  [-0.24734249376468087]
# state is :  [0.83550735 3.31620386]
# action is  [-1.7181086436938635]
# state is :  [1.02727386 3.83533019]
# high is  [0. 2.]
# observation state is  [1.        0.        1.1087854]
# action is  [0.8311716390983555]
# state is :  [0.         1.10878539]
# action is  [-1.7744828995470172]
# state is :  [0.06167306 1.23346114]
# action is  [0.0360317742089209]
# state is :  [0.11234877 1.01351418]
# action is  [-1.3244211497214895]
# state is :  [0.16749893 1.10300337]
# action is  [0.2961998990273327]
# state is :  [0.21896782 1.02937781]
# action is  [1.6300028320882216]
# state is :  [0.28080405 1.23672445]
# action is  [-1.1443110334729787]
# state is :  [0.3652576  1.68907109]
# action is  [1.4810099301527022]
# state is :  [0.45452345 1.78531688]
# action is  [1.5395618006651213]
# state is :  [0.57136065 2.33674401]
# action is  [-1.2843646837630733]
# state is :  [0.7200237  2.97326109]
# action is  [-0.7389893909202718]
# state is :  [0.88378161 3.27515825]
# high is  [0. 2.]
# observation state is  [ 1.        0.       -1.553939]
# action is  [1.672300317094686]
# state is :  [ 0.         -1.55393901]
# high is  [0. 2.]
# observation state is  [ 1.         0.        -1.1554184]
# action is  [-1.4637443303578994]
# state is :  [ 0.         -1.15541844]
# high is  [0. 2.]
# observation state is  [1.         0.         0.29642808]
# action is  [0.7041784986072215]
# state is :  [0.         0.29642809]
# action is  [1.8951700117728354]
# state is :  [0.02010274 0.40205487]
# action is  [1.3483301004499184]
# state is :  [0.05517306 0.70140641]
# action is  [1.4215655227042623]
# state is :  [0.1024238  0.94501473]
# action is  [-1.903389430831072]
# state is :  [0.16417046 1.23493317]
# action is  [1.576629940301384]
# state is :  [0.21777047 1.07200026]
# action is  [-1.8077220840500603]
# state is :  [0.29129721 1.47053472]
# action is  [0.1655980560699195]
# state is :  [0.36203584 1.41477267]
# action is  [1.8873096919957684]
# state is :  [0.44729817 1.70524651]
# action is  [-0.2938152946889847]
# state is :  [0.56293523 2.31274128]
# action is  [0.9603276934416853]
# state is :  [0.69638134 2.66892209]
# action is  [1.6160093010907532]
# state is :  [0.86108411 3.29405557]
# high is  [0. 2.]
# observation state is  [ 1.         0.        -1.0843285]
# action is  [1.9449486515415453]
# state is :  [ 0.        -1.0843285]
# high is  [0. 2.]
# observation state is  [1.       0.       1.461581]
# action is  [0.5191868274089257]
# state is :  [0.         1.46158105]
# action is  [0.707160039083957]
# state is :  [0.07697295 1.53945907]
# action is  [1.9757943880133713]
# state is :  [0.16213324 1.7032058 ]
# action is  [0.5583589159020224]
# state is :  [0.26816539 2.12064284]
# action is  [-0.7253793980416909]
# state is :  [0.38832133 2.40311881]
# action is  [0.6285814929387796]
# state is :  [0.51723574 2.57828834]
# action is  [-0.08961236671265072]
# state is :  [0.6694075  3.04343509]
# action is  [0.7004076946815485]
# state is :  [0.84417671 3.49538434]
# high is  [0. 2.]
# observation state is  [1.        0.        1.1606107]
# action is  [-0.37432502001361545]
# state is :  [0.         1.16061062]
# action is  [1.856576287989392]
# state is :  [0.05522309 1.10446187]
# action is  [1.5690960583391633]
# state is :  [0.12644032 1.42434458]
# action is  [0.25851429254143055]
# state is :  [0.21415466 1.75428676]
# action is  [-1.29213171959764]
# state is :  [0.31177741 1.95245501]
# action is  [-0.7833200262239286]
# state is :  [0.41121233 1.98869838]
# action is  [0.8266578304392929]
# state is :  [0.51976188 2.17099105]
# action is  [-1.3964077505458725]
# state is :  [0.65313662 2.66749483]
# action is  [1.0193923073887836]
# state is :  [0.79882632 2.913794  ]
# action is  [-0.11309888728691408]
# state is :  [0.97903164 3.60410626]
# high is  [0. 2.]
# observation state is  [1.       0.       0.619355]
# action is  [1.7760807203364606]
# state is :  [0.         0.61935502]
# action is  [1.6112907076905238]
# state is :  [0.04428836 0.88576713]
# action is  [-0.2207128585677669]
# state is :  [0.10232166 1.16066615]
# action is  [0.8885381147658848]
# state is :  [0.16252999 1.20416662]
# action is  [0.34240879367891797]
# state is :  [0.23547044 1.45880887]
# action is  [0.9143410026557]
# state is :  [0.31972772 1.68514554]
# action is  [-0.7231475337979565]
# state is :  [0.4226291  2.05802776]
# action is  [1.1765040573729948]
# state is :  [0.53548787 2.25717536]
# action is  [-0.5118031213156762]
# state is :  [0.6763052  2.81634648]
# action is  [1.5533684273208772]
# state is :  [0.83675584 3.20901283]
# action is  [1.275106213061521]
# state is :  [1.03669951 3.99887348]
# high is  [0. 2.]
# observation state is  [ 1.         0.        -1.2499256]
# action is  [-1.377216021766547]
# state is :  [ 0.         -1.24992558]
# high is  [0. 2.]
# observation state is  [ 1.         0.        -1.9128944]
# action is  [-1.0568540812404876]
# state is :  [ 0.         -1.91289437]
# high is  [0. 2.]
# observation state is  [1.        0.        0.2749176]
# action is  [-1.952777511829332]
# state is :  [0.         0.27491761]
# high is  [0. 2.]
# observation state is  [1.        0.        1.6329728]
# action is  [1.298983153696859]
# state is :  [0.         1.63297289]
# action is  [-1.6380672720179223]
# state is :  [0.09139102 1.82782036]
# action is  [0.6954217702549026]
# state is :  [0.17391893 1.65055816]
# action is  [0.5199915362545942]
# state is :  [0.26815163 1.88465403]
# action is  [0.011247499525438798]
# state is :  [0.37621987 2.16136494]
# action is  [0.5838285715377372]
# state is :  [0.49815025 2.43860759]
# action is  [-0.08922146341035431]
# state is :  [0.6423769  2.88453293]
# action is  [0.4843118362304901]
# state is :  [0.80840065 3.3204749 ]
# action is  [-1.4742462092589679]
# state is :  [1.00517611 3.9355093 ]
# high is  [0. 2.]
# observation state is  [ 1.         0.        -1.1959257]
# action is  [-1.990683211699651]
# state is :  [ 0.         -1.19592567]
# high is  [0. 2.]
# observation state is  [ 1.          0.         -0.62118155]
# action is  [1.6424782490230885]
# state is :  [ 0.         -0.62118156]
# high is  [0. 2.]
# observation state is  [1.        0.        0.9334847]
# action is  [-1.4696691102593227]
# state is :  [0.        0.9334847]
# action is  [-0.37914007838055364]
# state is :  [0.03565172 0.71303433]
# action is  [-0.6422799889404716]
# state is :  [0.06979654 0.68289645]
# action is  [-1.695100212801533]
# state is :  [0.10173951 0.63885936]
# action is  [-0.6569583945517574]
# state is :  [0.12477788 0.46076739]
# action is  [-1.6529271051605265]
# state is :  [0.1475561  0.45556438]
# action is  [0.21457381012560894]
# state is :  [0.16345066 0.31789124]
# action is  [-1.78483929071754]
# state is :  [0.18705667 0.47212019]
# action is  [1.0498753580759135]
# state is :  [0.20425017 0.34387008]
# action is  [1.5731754072860564]
# state is :  [0.23692398 0.65347611]
# action is  [-0.5236769185062577]
# state is :  [0.29019836 1.06548766]
# action is  [1.2280752668321284]
# state is :  [0.3502755  1.20154284]
# action is  [-1.3401883038965088]
# state is :  [0.43243158 1.64312158]
# action is  [-1.1658834878465]
# state is :  [0.52025174 1.75640318]
# action is  [-0.7693235954468989]
# state is :  [0.61796897 1.95434459]
# action is  [0.7486045676054949]
# state is :  [0.73164306 2.27348177]
# action is  [0.5219416523201081]
# state is :  [0.87598517 2.88684228]
# high is  [0. 2.]
# observation state is  [ 1.         0.        -1.7852235]
# action is  [-1.6324072304631536]
# state is :  [ 0.         -1.78522344]
# high is  [0. 2.]
# observation state is  [1.        0.        1.0558128]
# action is  [-0.4848674297537898]
# state is :  [0.         1.05581286]
# action is  [-0.22847389989185007]
# state is :  [0.04915414 0.98308274]
# action is  [-0.8992416449823915]
# state is :  [0.09843726 0.98566242]
# action is  [-1.0799145739946892]
# state is :  [0.14466151 0.92448494]
# action is  [-1.8764834950680864]
# state is :  [0.1881923  0.87061587]
# action is  [0.32864886264731696]
# state is :  [0.22466509 0.7294559 ]
# action is  [0.5374519629757613]
# state is :  [0.271957   0.94583815]
# action is  [0.7569121967815766]
# state is :  [0.33335294 1.22791871]
# action is  [1.8711830701658059]
# state is :  [0.41269621 1.58686546]
# action is  [1.335182989497087]
# state is :  [0.52111388 2.16835339]
# action is  [0.7513954524671447]
# state is :  [0.65821466 2.74201569]
# action is  [1.877443158922714]
# state is :  [0.82388987 3.31350411]
# action is  [-0.4319867593429887]
# state is :  [1.03116318 4.14546612]
# high is  [0. 2.]
# observation state is  [ 1.         0.        -1.4248749]
# action is  [0.8120667265113446]
# state is :  [ 0.         -1.42487486]
# high is  [0. 2.]
# observation state is  [1.         0.         0.06032369]
# action is  [1.4701619703868367]
# state is :  [0.         0.06032369]
# action is  [1.8913026008335416]
# state is :  [0.0140424  0.28084798]
# action is  [0.7466711597508477]
# state is :  [0.04279614 0.57507483]
# action is  [0.7295380622747198]
# state is :  [0.07875428 0.71916281]
# action is  [0.04234634245165303]
# state is :  [0.12313419 0.88759819]
# action is  [-1.94907350246022]
# state is :  [0.17243757 0.98606759]
# action is  [-0.1360278951255416]
# state is :  [0.21355731 0.82239477]
# action is  [-1.0651363834316725]
# state is :  [0.2616045  0.96094389]
# action is  [-0.2062057425644923]
# state is :  [0.31136183 0.99514653]
# action is  [-0.00340671663816261]
# state is :  [0.37106094 1.19398212]
# action is  [-1.0987400414616388]
# state is :  [0.44433215 1.46542439]
# action is  [0.6892536782204881]
# state is :  [0.52548239 1.62300462]
# action is  [-1.0810103580368349]
# state is :  [0.63061316 2.10261544]
# action is  [1.4334395440532783]
# state is :  [0.74974786 2.38269396]
# action is  [-1.2767164404807119]
# state is :  [0.90518788 3.10880058]
# high is  [0. 2.]
# observation state is  [1.        0.        1.9809004]
# action is  [0.6509528829758127]
# state is :  [0.        1.9809004]
# action is  [1.4895337687662757]
# state is :  [0.10392717 2.07854333]
# action is  [0.2544943512287974]
# state is :  [0.22291609 2.37977854]
# action is  [1.055072311073359]
# state is :  [0.35210402 2.58375856]
# action is  [-1.701168571407357]
# state is :  [0.50213775 3.00067454]
# action is  [-0.55620247703196]
# state is :  [0.65746148 3.10647462]
# action is  [-0.9158944292579063]
# state is :  [0.8315303  3.48137635]
# action is  [1.2405418721339516]
# state is :  [1.02644103 3.89821464]
# high is  [0. 2.]
# observation state is  [ 1.         0.        -1.7051075]
# action is  [-0.4496354654409225]
# state is :  [ 0.         -1.70510743]
# high is  [0. 2.]
# observation state is  [ 1.          0.         -0.59358466]
# action is  [0.008890755320422716]
# state is :  [ 0.         -0.59358466]
# high is  [0. 2.]
# observation state is  [ 1.         0.        -1.5043344]
# action is  [0.9211451945532856]
# state is :  [ 0.         -1.50433441]
# high is  [0. 2.]
# observation state is  [1.         0.         0.28059977]
# action is  [-1.5188943953273402]
# state is :  [0.         0.28059977]
# action is  [0.9075619679798925]
# state is :  [0.00263828 0.05276561]
# action is  [0.5045024141955627]
# state is :  [0.01218221 0.19087861]
# action is  [1.6693042957747433]
# state is :  [0.02596673 0.27569041]
# action is  [0.3859197755539774]
# state is :  [0.05324468 0.54555891]
# action is  [1.8743532539512997]
# state is :  [0.08541275 0.64336152]
# action is  [0.96726955955168]
# state is :  [0.13483756 0.98849621]
# action is  [0.40554185915363483]
# state is :  [0.196558   1.23440866]
# action is  [-0.17346577504164573]
# state is :  [0.26864355 1.44171101]
# action is  [0.534579547005682]
# state is :  [0.3493815  1.61475906]
# action is  [-1.0145712315787336]
# state is :  [0.44696568 1.95168354]
# action is  [0.8022422694149762]
# state is :  [0.55314924 2.12367132]
# action is  [1.6927559173401168]
# state is :  [0.68505098 2.63803474]
# action is  [-1.9422088475032147]
# state is :  [0.8533751 3.3664825]
# action is  [-0.9701337348593433]
# state is :  [1.03538905 3.6402789 ]
# high is  [0. 2.]
# observation state is  [ 1.         0.        -0.3659234]
# action is  [0.3703919694584421]
# state is :  [ 0.        -0.3659234]
# high is  [0. 2.]
# observation state is  [ 1.         0.        -0.6646694]
# action is  [-1.2039413037499562]
# state is :  [ 0.         -0.66466942]
# high is  [0. 2.]
# observation state is  [ 1.         0.        -0.6509196]
# action is  [-0.38957214516436833]
# state is :  [ 0.         -0.65091964]
# high is  [0. 2.]
# observation state is  [1.        0.        1.3922877]
# action is  [0.3251547784050497]
# state is :  [0.         1.39228772]
# action is  [0.6075215147096511]
# state is :  [0.07205305 1.44106093]
# action is  [1.88665031700407]
# state is :  [0.15136216 1.5861822 ]
# action is  [-1.3787154698261515]
# state is :  [0.25047558 1.98226839]
# action is  [0.37533637961162336]
# state is :  [0.34854356 1.96135961]
# action is  [-0.26687627999587615]
# state is :  [0.46223391 2.27380704]
# action is  [-1.860405256653615]
# state is :  [0.59064576 2.56823712]
# action is  [0.22521778943456194]
# state is :  [0.72598824 2.70684946]
# action is  [0.8456989107978239]
# state is :  [0.88791515 3.23853824]
# high is  [0. 2.]
# observation state is  [ 1.         0.        -0.7574049]
# action is  [-1.2434096915379724]
# state is :  [ 0.        -0.7574049]
# high is  [0. 2.]
# observation state is  [ 1.         0.        -0.8794792]
# action is  [-0.21637351115181858]
# state is :  [ 0.         -0.87947922]
# high is  [0. 2.]
# observation state is  [ 1.        0.       -1.337211]
# action is  [-1.5946555758029088]
# state is :  [ 0.         -1.33721104]
# high is  [0. 2.]
# observation state is  [1.        0.        1.6959037]
# action is  [0.3402100383087028]
# state is :  [0.         1.69590365]
# action is  [1.2111466226619663]
# state is :  [0.08734676 1.74693516]
# action is  [1.1844421090483275]
# state is :  [0.18704846 1.99403395]
# action is  [0.9397258202806129]
# state is :  [0.30260696 2.31117   ]
# action is  [1.3984760065904673]
# state is :  [0.43638876 2.67563617]
# action is  [-0.3930784183050733]
# state is :  [0.59650925 3.20240963]
# action is  [-1.8235197392226379]
# state is :  [0.77474756 3.56476637]
# action is  [-1.5481226535067871]
# state is :  [0.96554207 3.81589019]
# high is  [0. 2.]
# observation state is  [ 1.         0.        -1.4853954]
# action is  [-0.5472191645365854]
# state is :  [ 0.        -1.4853954]
# high is  [0. 2.]
# observation state is  [1.        0.        1.8391633]
# action is  [1.2531833100760643]
# state is :  [0.         1.83916333]
# action is  [-1.4244633147265136]
# state is :  [0.10135704 2.02714083]
# action is  [-0.6280621445527061]
# state is :  [0.19582499 1.88935902]
# action is  [0.3007651356216128]
# state is :  [0.29287907 1.94108157]
# action is  [-0.1580864387070755]
# state is :  [0.40301551 2.20272876]
# action is  [0.8836112914394478]
# state is :  [0.52667357 2.47316132]
# action is  [1.148900339769038]
# state is :  [0.67580849 2.98269838]
# action is  [1.1890038997296157]
# state is :  [0.85701748 3.62417966]
# high is  [0. 2.]
# observation state is  [1.         0.         0.61299914]
# action is  [-0.2912308785117488]
# state is :  [0.         0.61299917]
# action is  [-0.10045620528996624]
# state is :  [0.02846573 0.56931454]
# action is  [1.0625520670961457]
# state is :  [0.05724535 0.57559252]
# action is  [0.7569874414155997]
# state is :  [0.09613965 0.7778859 ]
# action is  [-1.818288618185543]
# state is :  [0.14431103 0.96342773]
# action is  [0.22847171451283055]
# state is :  [0.18423816 0.79854243]
# action is  [0.7026880051715501]
# state is :  [0.23274873 0.97021141]
# action is  [-0.7989115414726093]
# state is :  [0.29517894 1.24860436]
# action is  [-0.6410006816488525]
# state is :  [0.36252649 1.34695093]
# action is  [-1.7826490540210709]
# state is :  [0.43836544 1.51677906]
# action is  [1.9172909924321364]
# state is :  [0.51675178 1.56772672]
# action is  [-1.612853006023201]
# state is :  [0.628045   2.22586436]
# action is  [0.061693609560381724]
# state is :  [0.74927547 2.42460936]
# action is  [1.0744781316590202]
# state is :  [0.8965102  2.94469474]
# high is  [0. 2.]
# observation state is  [ 1.         0.        -0.4267011]
# action is  [-0.524696453998279]
# state is :  [ 0.         -0.42670111]
# high is  [0. 2.]
# observation state is  [ 1.         0.        -0.7208084]
# action is  [1.9328942291966218]
# state is :  [ 0.         -0.72080836]
# high is  [0. 2.]
# observation state is  [ 1.         0.        -0.9123487]
# action is  [-1.5141790376170583]
# state is :  [ 0.         -0.91234866]
# high is  [0. 2.]
# observation state is  [1.         0.         0.09393094]
# action is  [0.6501218685277776]
# state is :  [0.         0.09393094]
# action is  [0.10061001207799736]
# state is :  [0.00957246 0.19144922]
# action is  [0.30998846122295465]
# state is :  [0.02025846 0.21371996]
# action is  [-1.3040940870161042]
# state is :  [0.03402901 0.27541103]
# action is  [0.7490527166395098]
# state is :  [0.0392947  0.10531375]
# action is  [-0.465304920539213]
# state is :  [0.05165145 0.2471351 ]
# action is  [-0.7511982156557]
# state is :  [0.06245449 0.21606073]
# action is  [0.23807148780310827]
# state is :  [0.06996406 0.15019142]
# action is  [-1.3250105387472368]
# state is :  [0.08188068 0.23833239]
# action is  [0.981762730238775]
# state is :  [0.08692682 0.10092272]
# action is  [0.9978121978091683]
# state is :  [0.10259183 0.31330017]
# action is  [-0.4460723401011406]
# state is :  [0.12958087 0.53978097]
# action is  [1.3729650351683618]
# state is :  [0.15807008 0.56978402]
# action is  [1.607170009298558]
# state is :  [0.20275949 0.89378826]
# action is  [-1.2411335469972906]
# state is :  [0.26705417 1.28589355]
# action is  [1.3132286389268355]
# state is :  [0.33193626 1.2976419 ]
# action is  [1.3527988498913395]
# state is :  [0.41888785 1.73903184]
# action is  [1.1123488756856288]
# state is :  [0.53123836 2.2470102 ]
# action is  [-0.4817119625859796]
# state is :  [0.67092904 2.7938136 ]
# action is  [-1.5149506844127263]
# state is :  [0.83032115 3.18784225]
# action is  [-1.9136251904655652]
# state is :  [1.00603169 3.5142107 ]
# high is  [0. 2.]
# observation state is  [1.         0.         0.37886608]
# action is  [1.1905965999158807]
# state is :  [0.         0.37886606]
# action is  [-1.7146992307044804]
# state is :  [0.02787278 0.55745555]
# action is  [0.1138273683299591]
# state is :  [0.0439304  0.32115254]
# action is  [0.8263660315886985]
# state is :  [0.0624886  0.37116386]
# action is  [0.7429291683758907]
# state is :  [0.08958633 0.54195471]
# action is  [-1.234411403863465]
# state is :  [0.12561103 0.720494  ]
# action is  [1.1277927055455774]
# state is :  [0.15707568 0.62929302]
# action is  [0.8088936502150932]
# state is :  [0.20286493 0.91578485]
# action is  [-0.6286247490196497]
# state is :  [0.26227623 1.18822615]
# action is  [0.5301044580344203]
# state is :  [0.32669584 1.28839215]
# action is  [1.8683730625916617]
# state is :  [0.40712556 1.60859436]
# action is  [1.0407727957364257]
# state is :  [0.51641701 2.18582893]
# action is  [1.9965760603559226]
# state is :  [0.65203053 2.71227052]
# action is  [1.198191560698334]
# state is :  [0.82537344 3.46685815]
# action is  [0.6114130743161055]
# state is :  [1.03525783 4.19768773]
# high is  [0. 2.]
# observation state is  [ 1.         0.        -1.1797909]
# action is  [0.28182513771670825]
# state is :  [ 0.         -1.17979083]
# high is  [0. 2.]
# observation state is  [1.         0.         0.58074015]
# action is  [0.2837658104286236]
# state is :  [0.         0.58074014]
# action is  [-1.9942602558888192]
# state is :  [0.03116525 0.62330501]
# action is  [-0.6861840331651856]
# state is :  [0.04854206 0.34753613]
# action is  [0.48943282794464604]
# state is :  [0.0625921  0.28100077]
# action is  [-0.8585207664129739]
# state is :  [0.08265855 0.40132912]
# action is  [1.7092692061459895]
# state is :  [0.09938227 0.33447434]
# action is  [0.638916234939682]
# state is :  [0.13264621 0.66527879]
# action is  [-0.07696224516438654]
# state is :  [0.17566168 0.8603094 ]
# action is  [-0.6815129113174807]
# state is :  [0.22465342 0.97983481]
# action is  [1.8864785176807435]
# state is :  [0.27688763 1.04468425]
# action is  [-1.4378123100478648]
# state is :  [0.35352155 1.5326784 ]
# action is  [1.6158154045474022]
# state is :  [0.43235452 1.57665934]
# action is  [1.3999072405546262]
# state is :  [0.53901897 2.13328902]
# action is  [0.18983549727420845]
# state is :  [0.67543126 2.72824583]
# action is  [-0.5305378518875372]
# state is :  [0.83671359 3.22564662]
# action is  [-0.04580342146448446]
# state is :  [1.0218586 3.7029001]
# high is  [0. 2.]
# observation state is  [ 1.         0.        -1.3903722]
# action is  [-1.9624387542493271]
# state is :  [ 0.         -1.39037219]
# high is  [0. 2.]
# observation state is  [ 1.          0.         -0.44045973]
# action is  [0.35282755613005135]
# state is :  [ 0.         -0.44045972]
# high is  [0. 2.]
# observation state is  [1.        0.        1.2842535]
# action is  [-1.8787492427943633]
# state is :  [0.         1.28425352]
# action is  [1.7046568339783867]
# state is :  [0.05012206 1.00244113]
# action is  [0.5145674001626839]
# state is :  [0.11490783 1.29571546]
# action is  [-1.1907474836515148]
# state is :  [0.18785243 1.45889192]
# action is  [0.469932814572656]
# state is :  [0.25886952 1.42034195]
# action is  [1.0027501131670662]
# state is :  [0.34301066 1.6828228 ]
# action is  [-1.1391936084084135]
# state is :  [0.44728458 2.08547824]
# action is  [-1.9625160682427194]
# state is :  [0.55923399 2.23898832]
# action is  [-0.23017026214553082]
# state is :  [0.67635968 2.34251369]
# action is  [0.9141808011026593]
# state is :  [0.81523252 2.77745684]
# action is  [-0.8334708716405412]
# state is :  [0.98825741 3.46049775]
# high is  [0. 2.]
# observation state is  [ 1.         0.        -1.2694457]
# action is  [1.3618034558678658]
# state is :  [ 0.         -1.26944563]
# high is  [0. 2.]
# observation state is  [1.        0.        0.7471893]
# action is  [1.3235691921931214]
# state is :  [0.         0.74718929]
# action is  [-1.096698670522231]
# state is :  [0.04728623 0.94572467]
# action is  [-1.1028094482567443]
# state is :  [0.0881198  0.81667133]
# action is  [0.04809425691526137]
# state is :  [0.12398251 0.71725426]
# action is  [-1.351748685185318]
# state is :  [0.16484337 0.81721724]
# action is  [1.7197514492764596]
# state is :  [0.20171979 0.73752831]
# action is  [0.13499262387338673]
# state is :  [0.25900764 1.14575693]
# action is  [-0.7474309565706396]
# state is :  [0.32691248 1.35809689]
# action is  [-1.0476159054990672]
# state is :  [0.40125361 1.48682267]
# action is  [-0.889702735354319]
# state is :  [0.4823841 1.6226098]
# action is  [-0.6464178286307116]
# state is :  [0.57423779 1.8370738 ]
# action is  [1.0967607206811976]
# state is :  [0.68161316 2.14750738]
# action is  [-1.2644082220317223]
# state is :  [0.82084098 2.7845564 ]
# action is  [1.0114256530135646]
# state is :  [0.97802522 3.14368465]
# high is  [0. 2.]
# observation state is  [ 1.        0.       -0.816808]
# action is  [0.16272435991518597]
# state is :  [ 0.         -0.81680799]
# high is  [0. 2.]
# observation state is  [1.        0.        1.5329257]
# action is  [0.8877933345453606]
# state is :  [0.         1.53292567]
# action is  [1.9478790495783875]
# state is :  [0.08330473 1.66609467]
# action is  [0.33780650719054295]
# state is :  [0.18433888 2.02068283]
# action is  [1.0932171347167752]
# state is :  [0.29478019 2.2088263 ]
# action is  [-0.2096351207751339]
# state is :  [0.42431549 2.59070601]
# action is  [-0.6677938166825794]
# state is :  [0.56771717 2.86803355]
# action is  [0.9553625482261165]
# state is :  [0.72627447 3.17114602]
# action is  [-0.025211381808477373]
# state is :  [0.91690032 3.81251704]
# high is  [0. 2.]
# observation state is  [ 1.         0.        -0.9408541]
# action is  [1.128167920284504]
# state is :  [ 0.         -0.94085409]
# high is  [0. 2.]
# observation state is  [ 1.          0.         -0.08998552]
# action is  [-1.3683264942763156]
# state is :  [ 0.         -0.08998552]
# high is  [0. 2.]
# observation state is  [ 1.         0.        -1.8887849]
# action is  [-1.173702952935697]
# state is :  [ 0.         -1.88878488]
# high is  [0. 2.]
# observation state is  [ 1.         0.        -1.2879546]
# action is  [-0.729657289780524]
# state is :  [ 0.         -1.28795462]
# high is  [0. 2.]
# observation state is  [ 1.        0.       -1.950467]
# action is  [-1.0608760005604205]
# state is :  [ 0.         -1.95046698]
# high is  [0. 2.]
# observation state is  [ 1.         0.        -1.6622745]
# action is  [0.19066593887739947]
# state is :  [ 0.         -1.66227451]
# high is  [0. 2.]
# observation state is  [1.        0.        0.8623877]
# action is  [-1.1951111342956002]
# state is :  [0.         0.86238773]
# action is  [-0.5115900185580826]
# state is :  [0.03415605 0.68312106]
# action is  [1.4940717957201528]
# state is :  [0.06575578 0.63199461]
# action is  [-0.8190414330796298]
# state is :  [0.11102512 0.90538669]
# action is  [-0.8782391214824137]
# state is :  [0.15430654 0.86562835]
# action is  [-1.139371478259858]
# state is :  [0.19676472 0.84916366]
# action is  [1.724140075247755]
# state is :  [0.23800877 0.82488107]
# action is  [1.4933156571941746]
# state is :  [0.30102518 1.26032808]
# action is  [-0.24308860727068948]
# state is :  [0.38636018 1.70670001]
# action is  [-0.6552509294426394]
# state is :  [0.48400274 1.95285127]
# action is  [0.8790186394737916]
# state is :  [0.59418064 2.20355804]
# action is  [-1.1275920857983301]
# state is :  [0.73194481 2.75528334]
# action is  [0.1845560610452286]
# state is :  [0.88631395 3.08738273]
# high is  [0. 2.]
# observation state is  [1.        0.        1.3018265]
# action is  [1.0548759639399599]
# state is :  [0.         1.30182644]
# action is  [1.2647398366789058]
# state is :  [0.07300289 1.46005783]
# action is  [1.4005781167233895]
# state is :  [0.15822651 1.70447236]
# action is  [1.044092507648454]
# state is :  [0.25986323 2.03273441]
# action is  [1.7010094976771573]
# state is :  [0.37896621 2.38205957]
# action is  [-1.281769018504372]
# state is :  [0.52470027 2.91468117]
# action is  [-1.5875465443551144]
# state is :  [0.67960682 3.09813103]
# action is  [-0.34602923072277836]
# state is :  [0.84617504 3.33136448]
# action is  [0.308100408716641]
# state is :  [1.03822619 3.84102298]
# high is  [0. 2.]
# observation state is  [1.       0.       1.780651]
# action is  [1.412572564849019]
# state is :  [0.         1.78065093]
# action is  [1.216627853386481]
# state is :  [0.09962684 1.99253681]
# action is  [-0.7937504118909757]
# state is :  [0.21210822 2.24962757]
# action is  [-0.9869266883048882]
# state is :  [0.32653102 2.28845602]
# action is  [1.2704136185389836]
# state is :  [0.44558034 2.38098648]
# action is  [-0.12538164562508847]
# state is :  [0.59031958 2.89478474]
# action is  [-0.7207548337715028]
# state is :  [0.75499195 3.29344741]
# action is  [1.2770525353620572]
# state is :  [0.93995677 3.69929629]
# high is  [0. 2.]
# observation state is  [ 1.          0.         -0.71308947]
# action is  [-1.000146249507837]
# state is :  [ 0.         -0.71308949]
# high is  [0. 2.]
# observation state is  [1.       0.       1.346752]
# action is  [0.5324524084593856]
# state is :  [0.       1.346752]
# action is  [-0.14140575985574033]
# state is :  [0.07133099 1.42661986]
# action is  [1.6857697037186345]
# state is :  [0.14427409 1.45886188]
# action is  [0.7325635614784303]
# state is :  [0.23525198 1.81955791]
# action is  [-1.9018848582052472]
# state is :  [0.34046491 2.10425847]
# action is  [0.7966678031723182]
# state is :  [0.44393589 2.06941975]
# action is  [0.827059059071352]
# state is :  [0.56948803 2.5110428 ]
# action is  [0.005740698339994577]
# state is :  [0.72146315 3.03950237]
# action is  [-1.7567596620326706]
# state is :  [0.89824947 3.53572645]
# high is  [0. 2.]
# observation state is  [ 1.         0.        -1.7960585]
# action is  [-0.8378498482924996]
# state is :  [ 0.         -1.79605852]
# high is  [0. 2.]
# observation state is  [1.        0.        0.1172102]
# action is  [0.4631604206766595]
# state is :  [0.        0.1172102]
# action is  [0.46116761020093167]
# state is :  [0.00933421 0.18668427]
# action is  [-0.041923960083703804]
# state is :  [0.02247721 0.26285997]
# action is  [0.7042049524287153]
# state is :  [0.0361486  0.27342786]
# action is  [-0.056497225276420426]
# state is :  [0.05645681 0.40616416]
# action is  [-1.659118513487737]
# state is :  [0.0784573  0.44000969]
# action is  [-1.3682462422219128]
# state is :  [0.09095352 0.24992454]
# action is  [1.6470933962453809]
# state is :  [0.09659396 0.11280873]
# action is  [1.0464970848838435]
# state is :  [0.11820424 0.43220561]
# action is  [1.166024284613537]
# state is :  [0.15208559 0.67762705]
# action is  [1.3620290855586097]
# state is :  [0.20039338 0.96615567]
# action is  [0.1622687020265432]
# state is :  [0.26638094 1.31975117]
# action is  [-1.409754589909347]
# state is :  [0.34345707 1.54152279]
# action is  [-0.01578342489772755]
# state is :  [0.42258797 1.5826178 ]
# action is  [0.14922127387122686]
# state is :  [0.51698006 1.88784188]
# action is  [-0.47656095627528705]
# state is :  [0.63102595 2.28091791]
# action is  [-0.982452438960896]
# state is :  [0.76362165 2.65191385]
# action is  [-0.6449799432283703]
# state is :  [0.91478177 3.0232025 ]
# high is  [0. 2.]
# observation state is  [ 1.          0.         -0.06845073]
# action is  [0.9668191558337802]
# state is :  [ 0.         -0.06845073]
# action is  [-0.054448116430750204]
# state is :  [0.00382861 0.07657215]
# action is  [-1.616808305238902]
# state is :  [0.00739243 0.07127638]
# high is  [0. 2.]
# observation state is  [1.        0.        1.2125882]
# action is  [1.8829988520331677]
# state is :  [0.         1.21258823]
# action is  [0.45253868871158254]
# state is :  [0.0747519  1.49503805]
# action is  [-0.9453215191377606]
# state is :  [0.15569843 1.61893059]
# action is  [0.9701136657485514]
# state is :  [0.23537018 1.59343495]
# action is  [-0.7105669128428942]
# state is :  [0.33106289 1.91385423]
# action is  [-1.2200169443662006]
# state is :  [0.43361567 2.05105548]
# action is  [-1.0011799630565483]
# state is :  [0.54277411 2.18316888]
# action is  [0.12775321365605086]
# state is :  [0.66379296 2.42037693]
# action is  [-1.0068997915435718]
# state is :  [0.80887403 2.90162154]
# action is  [-0.3742667026264308]
# state is :  [0.973535   3.29321934]
# high is  [0. 2.]
# observation state is  [1.         0.         0.09927636]
# action is  [0.6866768617201435]
# state is :  [0.         0.09927637]
# action is  [-0.9733054955407088]
# state is :  [0.01011389 0.20227789]
# action is  [-0.5755489630663906]
# state is :  [0.01330726 0.06386736]
# action is  [1.3289374171901045]
# state is :  [ 0.01268302 -0.01248483]
# action is  [-1.2712570445652425]
# state is :  [0.02250141 0.19636779]
# action is  [1.9641365119220415]
# state is :  [0.0236291  0.02255387]
# action is  [0.3155233662698502]
# state is :  [0.04037383 0.33489453]
# action is  [-0.19337299084552662]
# state is :  [0.06099859 0.41249518]
# action is  [1.6624418957402773]
# state is :  [0.08245908 0.42920981]
# action is  [-1.8145763279751455]
# state is :  [0.1194766  0.74035034]
# action is  [-0.47745689617252784]
# state is :  [0.14735451 0.55755831]
# action is  [-1.0921241335422551]
# state is :  [0.17715732 0.59605614]
# action is  [0.47898557945254083]
# state is :  [0.2053779 0.5644116]
# action is  [1.590795671187759]
# state is :  [0.24483851 0.78921229]
# action is  [-1.2969427789880097]
# state is :  [0.30532008 1.20963138]
# action is  [0.5284974624856522]
# state is :  [0.36734702 1.24053882]
# action is  [-1.790685434391449]
# state is :  [0.44680547 1.58916898]
# action is  [-0.6445172367484213]
# state is :  [0.52903704 1.64463127]
# action is  [-0.14758195237934624]
# state is :  [0.62536106 1.92648038]
# action is  [1.6894332977254436]
# state is :  [0.74253034 2.34338561]
# action is  [-0.6692514427843226]
# state is :  [0.89772615 3.10391635]
# high is  [0. 2.]
# observation state is  [1.        0.        1.0918334]
# action is  [1.7241534974770683]
# state is :  [0.         1.09183333]
# action is  [1.4122860874458807]
# state is :  [0.06752282 1.35045635]
# action is  [1.2084594398067634]
# state is :  [0.14816796 1.61290291]
# action is  [1.4834076268560277]
# state is :  [0.24341254 1.90489163]
# action is  [1.0997345128160374]
# state is :  [0.35882078 2.30816476]
# action is  [1.334105944844847]
# state is :  [0.49564592 2.73650271]
# action is  [-0.6002670939452845]
# state is :  [0.66031185 3.29331855]
# action is  [1.839701298225684]
# state is :  [0.84347689 3.66330087]
# high is  [0. 2.]
# observation state is  [1.        0.        1.7250204]
# action is  [-0.25851546539523573]
# state is :  [0.         1.72502037]
# action is  [-0.37687131085333814]
# state is :  [0.08431215 1.68624306]
# action is  [-0.953492678271556]
# state is :  [0.16895573 1.69287158]
# action is  [-0.2598078179555272]
# state is :  [0.25275386 1.67596246]
# action is  [1.8291512270100858]
# state is :  [0.34398109 1.82454474]
# action is  [-0.1075256711858894]
# state is :  [0.46157337 2.35184564]
# action is  [-1.5187966088610843]
# state is :  [0.59506012 2.66973483]
# action is  [-0.6500300306974611]
# state is :  [0.73817683 2.86233424]
# action is  [-1.8082701658758604]
# state is :  [0.90165358 3.26953507]
# high is  [0. 2.]
# observation state is  [1.        0.        0.5563206]
# action is  [-1.3250633202638658]
# state is :  [0.         0.55632059]
# action is  [-1.02710037435403]
# state is :  [0.01787805 0.35756109]
# action is  [1.8779955205341703]
# state is :  [0.02872325 0.21690386]
# action is  [0.6304477759668017]
# state is :  [0.05473038 0.52014266]
# action is  [1.4313975107867045]
# state is :  [0.08751724 0.65573712]
# action is  [-0.5565471349309075]
# state is :  [0.13431728 0.93600092]
# action is  [1.003961428531709]
# state is :  [0.18196499 0.95295418]
# action is  [1.8410405147302171]
# state is :  [0.2439285  1.23927024]
# action is  [0.0812520530119265]
# state is :  [0.3287567  1.69656384]
# action is  [1.417607507888388]
# state is :  [0.42630177 1.95090156]
# action is  [1.2652203548151522]
# state is :  [0.5499854  2.47367249]
# action is  [1.9395074824162735]
# state is :  [0.70275848 3.05546163]
# action is  [-0.6265222491496938]
# state is :  [0.89431506 3.83113153]
# high is  [0. 2.]
# observation state is  [1.        0.        1.5984966]
# action is  [0.5792798123135916]
# state is :  [0.        1.5984965]
# action is  [0.5960126265849737]
# state is :  [0.08426942 1.68538848]
# action is  [-1.2515801842796157]
# state is :  [0.17616531 1.83791766]
# action is  [-0.8831474477168144]
# state is :  [0.26524642 1.78162228]
# action is  [1.2247024769354313]
# state is :  [0.35753444 1.84576047]
# action is  [0.7900738072907618]
# state is :  [0.47213145 2.29194009]
# action is  [1.686044064095261]
# state is :  [0.60970847 2.75154035]
# action is  [1.3635995057788506]
# state is :  [0.78140438 3.43391832]
# action is  [-0.9431354211382805]
# state is :  [0.98973769 4.16666608]
# high is  [0. 2.]
# observation state is  [ 1.         0.        -1.3325593]
# action is  [0.29037817964001045]
# state is :  [ 0.         -1.33255932]
# high is  [0. 2.]
# observation state is  [ 1.         0.        -0.8019215]
# action is  [-0.8247958914146367]
# state is :  [ 0.         -0.80192152]
# high is  [0. 2.]
# observation state is  [ 1.         0.        -1.3902353]
# action is  [-1.7554092204451162]
# state is :  [ 0.         -1.39023535]
# high is  [0. 2.]
# observation state is  [ 1.         0.        -1.2859294]
# action is  [0.9642752706656212]
# state is :  [ 0.         -1.28592941]
# high is  [0. 2.]
# observation state is  [ 1.          0.         -0.15061346]
# action is  [-1.4288382632432737]
# state is :  [ 0.         -0.15061346]
# high is  [0. 2.]
# observation state is  [ 1.        0.       -1.833781]
# action is  [-1.4924231428726644]
# state is :  [ 0.         -1.83378096]
# high is  [0. 2.]
# observation state is  [ 1.          0.         -0.89883137]
# action is  [-1.0183808198876396]
# state is :  [ 0.         -0.89883139]
# high is  [0. 2.]
# observation state is  [1.        0.        0.5417434]
# action is  [-1.2316434210423246]
# state is :  [0.         0.54174341]
# action is  [0.6556166156924665]
# state is :  [0.01784985 0.3569969 ]
# action is  [-0.8592213330119693]
# state is :  [0.04128615 0.46872607]
# action is  [1.6766850307789452]
# state is :  [0.05982608 0.37079868]
# action is  [-0.4035167063295533]
# state is :  [0.09318329 0.66714424]
# action is  [0.875830604499729]
# state is :  [0.12700345 0.6764031 ]
# action is  [0.5339137289740687]
# state is :  [0.17214217 0.90277442]
# action is  [1.9849658191537811]
# state is :  [0.22770874 1.11133142]
# action is  [0.25358290575920206]
# state is :  [0.30662803 1.57838579]
# action is  [1.7242809800346768]
# state is :  [0.3987684  1.84280748]
# action is  [-0.9967290058113027]
# state is :  [0.51840152 2.39266238]
# action is  [0.12424502548100813]
# state is :  [0.64914014 2.61477227]
# action is  [0.5762256059405515]
# state is :  [0.8034794  3.08678527]
# action is  [-1.1503264140594012]
# state is :  [0.98913195 3.71305101]
# high is  [0. 2.]
# observation state is  [1.        0.        0.9370389]
# action is  [-1.9093628182646691]
# state is :  [0.        0.9370389]
# action is  [-1.01340417744994]
# state is :  [0.03253172 0.65063448]
# action is  [0.2725676933329182]
# state is :  [0.05868264 0.52301834]
# action is  [-1.8170861032161083]
# state is :  [0.08907715 0.60789022]
# action is  [-1.6843714233004747]
# state is :  [0.10917949 0.40204685]
# action is  [1.651842601939335]
# state is :  [0.12073515 0.23111318]
# action is  [0.0023974107043645]
# state is :  [0.14919621 0.5692211 ]
# action is  [0.35154513962258704]
# state is :  [0.18324937 0.6810632 ]
# action is  [-1.5078001513172095]
# state is :  [0.22677257 0.87046409]
# action is  [1.1277194401744013]
# state is :  [0.26741855 0.8129195 ]
# action is  [-1.1723303163623848]
# state is :  [0.32643152 1.18025938]
# action is  [1.8774468577541628]
# state is :  [0.38867695 1.24490861]
# action is  [-1.6605738952520692]
# state is :  [0.47921439 1.81074892]
# action is  [-1.5019769955594784]
# state is :  [0.57458812 1.90747449]
# action is  [0.9164395282864164]
# state is :  [0.67907786 2.08979476]
# action is  [-1.2415838523849696]
# state is :  [0.81399373 2.69831748]
# action is  [1.6951808707965252]
# state is :  [0.96686154 3.0573562 ]
# high is  [0. 2.]
# observation state is  [ 1.        0.       -1.302917]
# action is  [1.302860802244259]
# state is :  [ 0.       -1.302917]
# high is  [0. 2.]
# observation state is  [1.        0.        1.8546916]
# action is  [-1.505872298856476]
# state is :  [0.         1.85469165]
# action is  [1.058655469346149]
# state is :  [0.08144054 1.62881081]
# action is  [1.6127963921771857]
# state is :  [0.17387164 1.84862204]
# action is  [0.5942726160848406]
# state is :  [0.2848861  2.22028917]
# action is  [0.085951036436962]
# state is :  [0.41089691 2.52021617]
# action is  [-0.41412104862070054]
# state is :  [0.55253104 2.83268263]
# action is  [-0.45110067560629785]
# state is :  [0.71074089 3.16419697]
# action is  [-0.05373121272478887]
# state is :  [0.89003231 3.58582846]
# high is  [0. 2.]
# observation state is  [1.        0.        1.4127052]
# action is  [-0.8267308647119243]
# state is :  [0.         1.41270523]
# action is  [1.0995759112929826]
# state is :  [0.06443478 1.2886956 ]
# action is  [-0.3121543839679042]
# state is :  [0.13953101 1.50192464]
# action is  [-0.5734394356624297]
# state is :  [0.21750154 1.55941051]
# action is  [-0.9936127676992599]
# state is :  [0.29926342 1.63523762]
# action is  [1.7189125416595048]
# state is :  [0.38462882 1.70730804]
# action is  [1.9099664460221422]
# state is :  [0.49695663 2.24655625]
# action is  [1.7755771890449394]
# state is :  [0.64148741 2.8906156 ]
# action is  [0.269392267888259]
# state is :  [0.82177457 3.60574305]
# action is  [-0.27453924087432924]
# state is :  [1.03154548 4.19541838]
# high is  [0. 2.]
# observation state is  [ 1.         0.        -0.6224806]
# action is  [0.9034211439789663]
# state is :  [ 0.         -0.62248056]
# high is  [0. 2.]
# observation state is  [ 1.        0.       -1.781753]
# action is  [-1.0492341539892607]
# state is :  [ 0.         -1.78175292]
# high is  [0. 2.]
# observation state is  [1.        0.        1.1532224]
# action is  [0.25702331865413264]
# state is :  [0.         1.15322239]
# action is  [-1.851614495041427]
# state is :  [0.05958879 1.19177589]
# action is  [-0.3841136977264932]
# state is :  [0.10752374 0.95869887]
# action is  [1.0772846348731147]
# state is :  [0.1566022  0.98156931]
# action is  [-0.9146188430704885]
# state is :  [0.21960891 1.26013418]
# action is  [-0.7097508550845109]
# state is :  [0.28392528 1.28632731]
# action is  [1.5795521318364556]
# state is :  [0.35342323 1.38995912]
# action is  [1.8834079477162051]
# state is :  [0.44774701 1.88647556]
# action is  [1.1603422191282147]
# state is :  [0.57243144 2.49368855]
# action is  [-1.6977093160431682]
# state is :  [0.72613134 3.073998  ]
# action is  [-1.976628057033464]
# state is :  [0.89199774 3.31732797]
# high is  [0. 2.]
# observation state is  [ 1.         0.        -1.0509824]
# action is  [-1.7994967364868146]
# state is :  [ 0.         -1.05098237]
# high is  [0. 2.]
# observation state is  [1.        0.        0.8057522]
# action is  [1.6006223670657702]
# state is :  [0.         0.80575222]
# action is  [0.8509727211890215]
# state is :  [0.05229228 1.04584557]
# action is  [1.0138527989265103]
# state is :  [0.11292692 1.21269282]
# action is  [-1.2468312749457424]
# state is :  [0.18539122 1.44928603]
# action is  [-1.5772231179082543]
# state is :  [0.2554167  1.40050964]
# action is  [-0.9917465791484279]
# state is :  [0.32308733 1.35341263]
# action is  [-1.0603116385694697]
# state is :  [0.39522595 1.44277239]
# action is  [1.537995433251154]
# state is :  [0.47385036 1.57248819]
# action is  [1.8287694521049311]
# state is :  [0.58112158 2.14542434]
# action is  [1.5528596576701985]
# state is :  [0.72269463 2.83146108]
# action is  [1.4445290159272375]
# state is :  [0.90071694 3.56044611]
# high is  [0. 2.]
# observation state is  [1.        0.        1.3965846]
# action is  [0.2899764758591128]
# state is :  [0.         1.39658457]
# action is  [-0.30837706986572266]
# state is :  [0.07200405 1.44008104]
# action is  [0.8736178033894864]
# state is :  [0.1443931  1.44778087]
# action is  [-1.9972949413601175]
# state is :  [0.22873022 1.68674244]
# action is  [1.8296509810732187]
# state is :  [0.30659041 1.55720395]
# action is  [-0.15882530935011419]
# state is :  [0.40949086 2.05800895]
# action is  [0.3247391751058095]
# state is :  [0.52613046 2.3327919 ]
# action is  [-0.25201805658729715]
# state is :  [0.66403775 2.75814595]
# action is  [-1.8847100365009033]
# state is :  [0.82316623 3.18256947]
# action is  [-0.0753931263204457]
# state is :  [0.99565821 3.44983964]
# high is  [0. 2.]
# observation state is  [ 1.         0.        -1.1583955]
# action is  [1.0279418552243285]
# state is :  [ 0.         -1.15839554]
# high is  [0. 2.]
# observation state is  [ 1.          0.         -0.40478814]
# action is  [0.6532196548783449]
# state is :  [ 0.         -0.40478813]
# high is  [0. 2.]
# observation state is  [1.         0.         0.71468127]
# action is  [-0.6544766513855698]
# state is :  [0.         0.71468126]
# action is  [-0.533485768964435]
# state is :  [0.03082549 0.61650977]
# action is  [-1.2362032205075062]
# state is :  [0.05880561 0.55960236]
# action is  [-1.8079064228611856]
# state is :  [0.07971814 0.41825066]
# action is  [1.508772661843138]
# state is :  [0.09005764 0.20679   ]
# action is  [1.6851120721731778]
# state is :  [0.11508553 0.50055786]
# action is  [0.4389822009472302]
# state is :  [0.15705795 0.83944842]
# action is  [1.5765686009804245]
# state is :  [0.20818823 1.02260553]
# action is  [-0.16535583221504258]
# state is :  [0.27889356 1.41410652]
# action is  [-1.3227987201566545]
# state is :  [0.35868217 1.59577224]
# action is  [1.9886142572191305]
# state is :  [0.44171381 1.66063286]
# action is  [0.022174403793910002]
# state is :  [0.55569091 2.27954206]
# action is  [0.6950854812085558]
# state is :  [0.68961671 2.678516  ]
# action is  [0.14106811243729922]
# state is :  [0.85261471 3.25995997]
# action is  [0.6930359224761298]
# state is :  [1.04490835 3.84587281]
# 0.0123

# %%
def select_action_simple(state):
    if (state[0] < 0):
        return 0
    else:
        return 1

goodness_score(select_action_simple)

# %%
def select_action_good(state):
    if state[2]+state[3] < 0:
        return 0
    else:
        return 1

goodness_score(select_action_good)

# %%
class PolicyNN(nn.Module):
    def __init__(self):
        super(PolicyNN, self).__init__()
        self.fc = nn.Linear(4, 2)

    def forward(self, x):
        x = self.fc(x)
        return F.softmax(x, dim=1)

def select_action_from_policy(model, state):
    state = torch.from_numpy(state).float().unsqueeze(0)
    probs = model(state)
    m = Categorical(probs)
    action = m.sample()
    return action.item(), m.log_prob(action)

def select_action_from_policy_best(model, state):
    state = torch.from_numpy(state).float().unsqueeze(0)
    probs = model(state)
    if probs[0][0] > probs[0][1]:
        return 0
    else:
        return 1

# %%
model_untrained = PolicyNN()

print(
    goodness_score(lambda state: select_action_from_policy(model_untrained, state)[0]),
    goodness_score(lambda state: select_action_from_policy_best(model_untrained, state))
)

# %%
model = PolicyNN()
optimizer = optim.Adam(model.parameters(), lr=0.01)

def train_wont_work(num_episodes=100):
    num_steps = 500
    for episode in range(num_episodes):
        state = env.reset()
        for t in range(1, num_steps+1):
            action = select_action(state)
            state, _, done, _ = env.step(action)
            if done:
                break
        loss = 1.0 - t / num_steps
        # this doesn't actually work, because
        # the loss function is not an explicit
        # function of the model's output; it's
        # a function of book keeping variables
        optimizer.zero_grad()
        loss.backward() # AttributeError: 'float' object has no attribute 'backward'
        optimizer.step()

def train_simple(num_episodes=10*1000):
    num_steps = 500
    ts = []
    for episode in range(num_episodes):
        state = env.reset()[0]
        probs = []
        for t in range(1, num_steps+1):
            action, prob = select_action_from_policy(model, state)
            probs.append(prob)
            #state, _, done, _ = env.step(action)
            state, reward, done, truncated, info = env.step(action)
            if done:
                break
        loss = 0
        for i, prob in enumerate(probs):
            loss += -1 * (t - i) * prob
        print(episode, t, loss.item())
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        ts.append(t)
        if len(ts) > 10 and sum(ts[-10:])/10.0 >= num_steps * 0.95:
            print('Stopping training, looks good...')
            return

train_simple()

# %%
print(
    goodness_score(lambda state: select_action_from_policy(model, state)[0]),
    goodness_score(lambda state: select_action_from_policy_best(model, state))
)
